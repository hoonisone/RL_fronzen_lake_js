# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
def get_result_dict(file_name):
    with open(file_name, "r") as f:
        return json.loads(f.readline())

def show_mean_step_num_graph(file_name):

    result = get_result_dict(file_name)

    data = np.array([[episode["step_num"] for episode in test]for test in result])
    mean_action_step = data.mean(axis=0)
    plt.plot(mean_action_step)

# %%
show_mean_step_num_graph(file_name = "./../data/test_result_10x10_no_forget.txt")

# %%
show_mean_step_num_graph(file_name = "./../data/result(10x10, no_forget).txt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 show_mean_step_num_graph(file_name = "./../data/result(10x10, no_forget).txt")
#
# Cell In[25], line 9, in show_mean_step_num_graph(file_name)
#       5 def show_mean_step_num_graph(file_name):
#       7     result = get_result_dict(file_name)
# ----> 9     data = np.array([[episode["step_num"] for episode in test]for test in result])
#      10     mean_action_step = data.mean(axis=0)
#      11     plt.plot(mean_action_step)
#
# Cell In[25], line 9, in <listcomp>(.0)
#       5 def show_mean_step_num_graph(file_name):
#       7     result = get_result_dict(file_name)
# ----> 9     data = np.array([[episode["step_num"] for episode in test]for test in result])
#      10     mean_action_step = data.mean(axis=0)
#      11     plt.plot(mean_action_step)
#
# Cell In[25], line 9, in <listcomp>(.0)
#       5 def show_mean_step_num_graph(file_name):
#       7     result = get_result_dict(file_name)
# ----> 9     data = np.array([[episode["step_num"] for episode in test]for test in result])
#      10     mean_action_step = data.mean(axis=0)
#      11     plt.plot(mean_action_step)
#
# TypeError: string indices must be integers
